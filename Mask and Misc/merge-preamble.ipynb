# %%
import xarray as xr
import gcsfs
from xmitgcm.llcreader.llcmodel import faces_dataset_to_latlon
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import intake
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
cat = intake.Catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean.yaml")
ds_faces = cat["ECCOv4r3"].to_dask()

# %%
ds_faces1 = xr.open_zarr(gcsfs.GCSMap('pangeo-data/ECCO_layers.zarr'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-41163e55ac5d> in <module>
# ----> 1 ds_faces1 = xr.open_zarr(gcsfs.GCSMap('pangeo-data/ECCO_layers.zarr'))
#
# ...

# %%
#Apply Ryan's code to the dataset
ds_ll=faces_dataset_to_latlon(ds_faces1, metric_vector_pairs=[('LaHw3RHO','LaHs3RHO')])
dsnew = (ds_ll.reset_coords(drop=True).roll(i=180, roll_coords=False)).roll(i_g=180, roll_coords=False)
#Apply Ryan's code to the dataset
ds_ll = faces_dataset_to_latlon(ds_faces)
dsold = (ds_ll.reset_coords(drop=True).roll(i=180, roll_coords=False))

# %%
array = (dsnew, dsold)
ds_ll = xr.merge(array, compat='broadcast_equals')

# %%
#Exclude 1992 and put the Atlantic in the middle 
ds = (ds_ll.reset_coords(drop=True).roll(i=180, roll_coords=False)).roll(i_g=180, roll_coords=False)

#Make a corresponding dataset of the coordinates of ds, with the same conditions as above(?)
coords = (ds_ll.coords.to_dataset().reset_coords().roll(i=180, roll_coords=False)).roll(i_g=180, roll_coords=False)
